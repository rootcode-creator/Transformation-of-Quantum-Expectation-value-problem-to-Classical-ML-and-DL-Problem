# %%
import warnings
warnings.filterwarnings('ignore')

# %%
'''


Electronic structure problem with classical shadows, as presented in https://arxiv.org/abs/2103.07510
This code uses Qiskit as platform. 
The shadow is constructed based on derandomized Hamiltonian.
The molecules tested are: H2 (6-31s basis), LiH (sto3g basis), BeH2 (sto3g), H2O (sto3g), and NH3 (sto3g).
The coordinates for NH3 were taken from 'Algorithms for Computer Detection of Symmetry Elementsin Molecular Systems'. 
'''

import time
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit, execute
from qiskit_aer.primitives import Estimator as AerEstimator 
from qiskit_aer import QasmSimulator

from qiskit.quantum_info import SparsePauliOp

from qiskit_nature.units import DistanceUnit
from qiskit_nature.second_q.drivers import PySCFDriver
from qiskit_nature.second_q.algorithms import GroundStateEigensolver
from qiskit_nature.second_q.mappers import BravyiKitaevMapper, JordanWignerMapper, ParityMapper

from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock
from qiskit_nature.second_q.algorithms import VQEUCCFactory
from qiskit.algorithms.minimum_eigensolvers import VQE
from qiskit.algorithms.optimizers import SLSQP, COBYLA, SPSA

# Estimator primitive is based on the Statevector construct = algebraic simulation
from qiskit.primitives import Estimator 
from qiskit.utils import algorithm_globals

from modified_derandomization import modified_derandomized_classical_shadow
from data_acquisition_shadow import derandomized_classical_shadow
from prediction_shadow import estimate_exp

import qiskit_nature
qiskit_nature.settings.use_pauli_sum_op = False
import h5py
H5PY_DEFAULT_READONLY=1

# %%
'''
DEFINING DRIVERS FOR THE MOLECULES
'''


H2_driver = PySCFDriver(
    atom="H 0 0 0; H 0 0 0.735",
    basis="6-31g",
    charge=0,
    spin=0,
    unit=DistanceUnit.ANGSTROM,
)

LiH_driver = PySCFDriver(
    atom="Li 0 0 0; H 0 0 1.599",
    basis="sto3g",
    charge=0,
    spin=0,
    unit=DistanceUnit.ANGSTROM,
)

BeH2_driver = PySCFDriver(
    atom="Be 0 0 0; H 0 0 1.3264; H 0 0 -1.3264",
    basis="sto3g",
    charge=0,
    spin=0,
    unit=DistanceUnit.ANGSTROM,
)

H2O_driver = PySCFDriver(
    atom="O 0.0 0.0 0.0; H 0.757 0.586 0.0; H -0.757 0.586 0.0",
    basis="sto3g",
    charge=0,
    spin=0,
    unit=DistanceUnit.ANGSTROM,
)

NH3_driver = PySCFDriver(
    atom="N 0 0 0; H 0 0 1.008000; H 0.950353 0 -0.336000; H -0.475176 -0.823029 -0.336000",
    basis="sto3g",
    charge=0,
    spin=0,
    unit=DistanceUnit.ANGSTROM,
)

# %%
'''
FORMATTING HAMILTONIAN
'''

def process_hamiltonian(hamiltonian, derandomize = False):

    hamiltonian_observables = []
    hamiltonian_coefficients = []

    for observable in hamiltonian.paulis:
        op_list = []
        for op_index, pauli_op in enumerate(observable):
            pauli_op = str(pauli_op)
            if pauli_op == 'I' or pauli_op == 'X' or pauli_op == 'Y' or pauli_op == 'Z':
                op_list.append((pauli_op, op_index))
        hamiltonian_observables.append(op_list)
    
    hamiltonian_coefficients = hamiltonian.coeffs.real
    
    system_size = len(hamiltonian_observables[0])

    # removing all occurrences of Pauli-I, for all-Pauli-I there is an empty list left
    # these observables are needed for estimate_exp()
    observables_xyze = []

    for observable in hamiltonian_observables:
        XYZE = []
        for pauli in observable:
            if pauli[0] != 'I':
                XYZE.append(pauli)
        observables_xyze.append(XYZE)   
    
    # derandomisation procedure requires that coefficients are non-negative
    if derandomize == True:
        absolute_coefficients = [abs(coeffcient) for coeffcient in hamiltonian_coefficients]

        # removing the empty list as well
        # these observables are needed for derandomisation procedure
        observables_xyz = []
        for idx, observable in enumerate(observables_xyze):
            if observable:
                observables_xyz.append(observable)
            else:
                absolute_coefficients.pop(idx)
        
        return system_size, observables_xyze, observables_xyz, hamiltonian_coefficients, absolute_coefficients
    
    return system_size, observables_xyze, hamiltonian_coefficients








'''
COST FUNCTION AND HELPER FUNCTIONS
''' 

def basis_change_circuit(pauli_op):

    #   Generating circuit with just the basis change operators
    #
    #       pauli_op: n-qubit Pauli operator

    basis_change = QuantumCircuit(ansatz.num_qubits, ansatz.num_qubits)

    for idx, op in enumerate(pauli_op):
        
        if op == 'X':
            basis_change.h(idx)
        if op == 'Y':
            basis_change.h(idx)
            basis_change.p(-np.pi/2, idx)
            
    return basis_change

    
    


def ground_state_energy_from_shadow(operators, params):
    
    backend = QasmSimulator(method='statevector', shots=1)
    
    pauli_op_dict = Counter(tuple(x) for x in operators)    
    

    shadow = []
    for pauli_op in pauli_op_dict:
        
        qc = ansatz.bind_parameters(params)
        qc = qc.compose(basis_change_circuit(pauli_op))                                  
        qc.measure(reversed(range(system_size)), range(system_size))                      
        
        result = execute(qc, backend, shots=pauli_op_dict[pauli_op]).result()
        counts = result.get_counts()    # given in order q0 q1 ... qn-1 after register reversal in qc.measure
        
        for count in counts:
            for _ in range(counts[count]): # number of repeated measurement values

                output_str = list(count)   
                output = [int(i) for i in output_str]
                eigenvals = [x+1 if x == 0 else x-2 for x in output]
                snapshot = [(op, eigenval) for op, eigenval in zip(pauli_op, eigenvals)]
                
                shadow.append(snapshot)
    

    expectation_value = 0.0
    for term, weight in zip(observables_xyze, hamiltonian_coefficients):
        
        sum_product, match_count = estimate_exp(shadow, term)
        
        if match_count != 0:
            expectation_value += (weight * sum_product / match_count)

    return expectation_value

# %%
'''
EXPERIMENTS
'''

start_time = time.time()
all_molecules_rmse_errors = []



# CALCULATING FERMIONIC HAMILTONIAN AND CONVERTING TO QUBIT HAMILTONIAN

MOLECULES = ['H2']

for molecule in MOLECULES:   
    
    rmse_errors = []
    
    if molecule == 'H2':
        problem = H2_driver.run()
    if molecule == 'LiH':
        problem = LiH_driver.run()
    if molecule == 'BeH2':
        problem = BeH2_driver.run()
    if molecule == 'H2O':
        problem = H2O_driver.run()
    if molecule == 'NH3':
        problem = NH3_driver.run()

    hamiltonian = problem.hamiltonian
    second_q_op = hamiltonian.second_q_op()

    p_mapper = ParityMapper() #(num_particles=problem.num_particles)  #ParityMapper()
    bkencoded_hamiltonian = p_mapper.map(second_q_op)
    #print('Qubit Hamiltonian in Bravyi-Kitaev encoding', bkencoded_hamiltonian)


    # process the Hamiltonian to obtain properly formatted data
    hamiltonian_data = process_hamiltonian(bkencoded_hamiltonian, derandomize = True)
    system_size, observables_xyze, observables_xyz, hamiltonian_coefficients, absolute_coefficients = hamiltonian_data

    '''
    VARIATIONAL ANSATZ
    '''
    ansatz = UCCSD(
        problem.num_spatial_orbitals,
        problem.num_particles,
        p_mapper,
        initial_state=HartreeFock(
            problem.num_spatial_orbitals,
            problem.num_particles,
            p_mapper,
        ),
    )
    
    '''
    Running VQE on the Hamiltonian obtained from PySCFDriver using Statevector simulator (Estimator primitive)
    '''
    #estimator = Estimator()
    # If shots = None, it calculates the exact expectation values. Otherwise, it samples from normal distributions 
    # with standard errors as standard deviations using normal distribution approximation.
    #estimator.set_options(shots = None)
    #estimator = AerEstimator()
    #estimator.set_options(approximation=False, shots=None)
    
    #vqe_solver = VQE(estimator, ansatz, SLSQP())
    vqe_solver = VQE(Estimator(), ansatz, SLSQP())
    vqe_solver.initial_point = np.zeros(ansatz.num_parameters)

    calc = GroundStateEigensolver(p_mapper, vqe_solver)
    result = calc.solve(problem)
    print(result.raw_result)
    


    #print('NUMBER OF OPERATORS | DERANDOMISED OPERATORS | AVERAGE RMSE ERROR\n')
    measurement_range = [50, 250, 500, 750, 1000, 1250, 1500, 1750]   

    for num_operators in measurement_range:   

        derandomized_hamiltonian = derandomized_classical_shadow(observables_xyz, 50, 
                                                                          system_size, weight=absolute_coefficients)

        tuples = (tuple(pauli) for pauli in derandomized_hamiltonian)
        counts = Counter(tuples)
        print('Original derandomized Hamiltonian', counts)
        
        # derandomized classical shadow will usually either undergenerate or overgenerate derandomized operators
        # adjusting for this issue: 
        
        while sum(counts.values()) != num_operators:
            for key, value in zip(counts.keys(), counts.values()):
                sum_counts = sum(counts.values())
                if sum_counts == num_operators:
                    break
                if sum_counts < num_operators:
                    # generate additional operators from the existing ones by increasing the number of counts
                    counts[key] += 1
                if sum_counts > num_operators:
                    # remove the element with highest count
                    max_element_key = [k for k, v in counts.items() if v == max(counts.values())][0]
                    counts[max_element_key] -= 1
    
        print('Size-adjusted derandomized Hamiltonian', counts)
        
        # translate the Counter to a set of derandomized operators
        new_derandomized_hamiltonian = []
        for key, value in counts.items():
            for _ in range(value):
                new_derandomized_hamiltonian.append(list(key))
        #print('Size-adjusted derandomized Hamiltonian', new_derandomized_hamiltonian)
        
        
        expectation_values = []
        num_experiments = 10   

        
        for iteration in range(num_experiments):

            expectation_value = ground_state_energy_from_shadow(new_derandomized_hamiltonian, result.raw_result.optimal_point)
            expectation_values.append(expectation_value)

            print("EXPERIMENT {}: GROUND STATE ENERGY FOUND = {}".format(iteration, expectation_value))


        rmse_derandomised_cs = np.sqrt(np.sum([(expectation_values[i] - result.raw_result.optimal_value)**2 
                                               for i in range(num_experiments)])/num_experiments)

        rmse_errors.append(rmse_derandomised_cs)

        print('{} | {} | {}'.format(num_operators, counts, rmse_derandomised_cs))
        
    all_molecules_rmse_errors.append(rmse_errors)
    
    elapsed_time = time.time() - start_time
    print("Execution time = ", time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# {   'aux_operators_evaluated': {   'AngularMomentum': (   7.375797195230405e-11,
#                                                           {}),
#                                    'Magnetization': (-0.0, {}),
#                                    'ParticleNumber': (2.0, {}),
#                                    'XDipole': (0.0, {}),
#                                    'YDipole': (0.0, {}),
#                                    'ZDipole': (1.3889483102765505, {})},
#     'cost_function_evals': 116,
#     'eigenvalue': -1.871583225559378,
#     'optimal_circuit': <qiskit_nature.second_q.circuit.library.ansatzes.uccsd.UCCSD object at 0x7ff45999a9d0>,
#     'optimal_parameters': {   ParameterVectorElement(t[1]): -0.005517160930781669,
#                               ParameterVectorElement(t[2]): -1.8163328718102069e-07,
#                               ParameterVectorElement(t[3]): -2.4809137967560493e-07,
#                               ParameterVectorElement(t[4]): -0.005518272308689623,
#                               ParameterVectorElement(t[5]): -6.452781725733671e-07,
#                               ParameterVectorElement(t[6]): -0.07574007467546673,
#                               ParameterVectorElement(t[7]): -2.126846785554807e-07,
#                               ParameterVectorElement(t[8]): 0.04521376397752663,
#                               ParameterVectorElement(t[9]): -4.2748456042529094e-07,
#                               ParameterVectorElement(t[10]): -0.0511775453951898,
#                               ParameterVectorElement(t[11]): -7.002177588733599e-07,
#                               ParameterVectorElement(t[12]): 0.04532785215546126,
#                               ParameterVectorElement(t[13]): 1.2022658010594126e-07,
#                               ParameterVectorElement(t[14]): -0.043199867960206396,
#                               ParameterVectorElement(t[0]): 2.2665175621193487e-07},
#     'optimal_point': array([ 2.26651756e-07, -5.51716093e-03, -1.81633287e-07, -2.48091380e-07,
#        -5.51827231e-03, -6.45278173e-07, -7.57400747e-02, -2.12684679e-07,
#         4.52137640e-02, -4.27484560e-07, -5.11775454e-02, -7.00217759e-07,
#         4.53278522e-02,  1.20226580e-07, -4.31998680e-02]),
#     'optimal_value': -1.871583225559378,
#     'optimizer_evals': None,
#     'optimizer_result': <qiskit.algorithms.optimizers.optimizer.OptimizerResult object at 0x7ff454610c10>,
#     'optimizer_time': 54.93912100791931}
# Original derandomized Hamiltonian Counter({('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 9, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 9, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 7, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 6, ('Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 4, ('X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 3, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X'): 3, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('Z', 'Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Z'): 1, ('Y', 'Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'X', 'Z', 'Y', 'Y', 'Z', 'Z'): 1, ('Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 1, ('Y', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 1, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z'): 1, ('Z', 'Z', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('Y', 'X', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('X', 'Z', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Z'): 1, ('Y', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z'): 1})
# Size-adjusted derandomized Hamiltonian Counter({('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 3, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 3, ('Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 3, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 3, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 3, ('X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 3, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X'): 3, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('Z', 'Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Z'): 1, ('Y', 'Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'X', 'Z', 'Y', 'Y', 'Z', 'Z'): 1, ('Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 1, ('Y', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 1, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z'): 1, ('Z', 'Z', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('Y', 'X', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('X', 'Z', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Z'): 1, ('Y', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z'): 1})
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -2.3129737583248238
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -2.0284801259258773
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -2.0353317217178764
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -2.0274804958944697
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -1.7376589523846864
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -1.963630666931492
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -1.6453584620441917
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -1.9779349320238362
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -2.000325631374906
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -2.3657277728357524
# 50 | Counter({('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 3, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 3, ('Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 3, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 3, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 3, ('X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 3, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X'): 3, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('Z', 'Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Z'): 1, ('Y', 'Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'X', 'Z', 'Y', 'Y', 'Z', 'Z'): 1, ('Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 1, ('Y', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 1, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z'): 1, ('Z', 'Z', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('Y', 'X', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('X', 'Z', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Z'): 1, ('Y', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z'): 1}) | 0.24904015355234405
# Original derandomized Hamiltonian Counter({('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 9, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 9, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 7, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 6, ('Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 4, ('X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 3, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X'): 3, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('Z', 'Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Z'): 1, ('Y', 'Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'X', 'Z', 'Y', 'Y', 'Z', 'Z'): 1, ('Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 1, ('Y', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 1, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z'): 1, ('Z', 'Z', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('Y', 'X', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('X', 'Z', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Z'): 1, ('Y', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z'): 1})
# Size-adjusted derandomized Hamiltonian Counter({('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 14, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 14, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 12, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 11, ('Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 9, ('X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 8, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X'): 8, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'X', 'Z'): 6, ('Z', 'Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Z'): 6, ('Y', 'Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'Z'): 6, ('Z', 'X', 'X', 'Z', 'Y', 'Y', 'Z', 'Z'): 6, ('Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 6, ('X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 6, ('Y', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 6, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 6, ('Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 6, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 6, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z'): 6, ('Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 6, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 6, ('X', 'X', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 6, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 6, ('Z', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 6, ('X', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z'): 6, ('Z', 'Z', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 6, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 6, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'Y', 'X'): 6, ('Y', 'X', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 6, ('X', 'Z', 'X', 'Z', 'X', 'X', 'X', 'Z'): 6, ('X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 6, ('Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Z'): 6, ('Y', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 6, ('Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 6, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 6, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 6, ('Z', 'Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z'): 6})
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -1.8264933429687442
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -1.7574227720368296
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -1.724445607700607
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -1.8511651020449436
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -1.7287615061851596
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -1.9425752063140562
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -1.7273715176866247
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -1.8558978516558162
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -1.906876918604182
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -1.8538130464401428
# 250 | Counter({('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 14, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 14, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 12, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 11, ('Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 9, ('X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 8, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X'): 8, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'X', 'Z'): 6, ('Z', 'Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Z'): 6, ('Y', 'Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'Z'): 6, ('Z', 'X', 'X', 'Z', 'Y', 'Y', 'Z', 'Z'): 6, ('Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 6, ('X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 6, ('Y', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 6, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 6, ('Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 6, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 6, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z'): 6, ('Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 6, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 6, ('X', 'X', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 6, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 6, ('Z', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 6, ('X', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z'): 6, ('Z', 'Z', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 6, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 6, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'Y', 'X'): 6, ('Y', 'X', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 6, ('X', 'Z', 'X', 'Z', 'X', 'X', 'X', 'Z'): 6, ('X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 6, ('Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Z'): 6, ('Y', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 6, ('Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 6, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 6, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 6, ('Z', 'Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z'): 6}) | 0.09229001113378285
# Original derandomized Hamiltonian Counter({('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 9, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 9, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 7, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 6, ('Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 4, ('X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 3, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X'): 3, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('Z', 'Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Z'): 1, ('Y', 'Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'X', 'Z', 'Y', 'Y', 'Z', 'Z'): 1, ('Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 1, ('Y', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 1, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z'): 1, ('Z', 'Z', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('Y', 'X', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('X', 'Z', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Z'): 1, ('Y', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z'): 1})
# Size-adjusted derandomized Hamiltonian Counter({('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 21, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 21, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 19, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 18, ('Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 16, ('X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 14, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X'): 14, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'X', 'Z'): 13, ('Z', 'Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Z'): 13, ('Y', 'Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'Z'): 13, ('Z', 'X', 'X', 'Z', 'Y', 'Y', 'Z', 'Z'): 13, ('Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 13, ('X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 13, ('Y', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 13, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 13, ('Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 13, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 13, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z'): 13, ('Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 13, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 13, ('X', 'X', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 13, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 13, ('Z', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 13, ('X', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z'): 13, ('Z', 'Z', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 13, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 13, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'Y', 'X'): 13, ('Y', 'X', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 13, ('X', 'Z', 'X', 'Z', 'X', 'X', 'X', 'Z'): 13, ('X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 13, ('Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Z'): 13, ('Y', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 13, ('Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 13, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 13, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 13, ('Z', 'Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z'): 13})
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -1.8705920829453162
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -1.8595453439184328
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -1.9280726836678903
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -1.7962741183796171
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -1.675401500862974
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -1.8739341161818777
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -1.7375945614678578
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -1.7984914463579496
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -1.8006677655204206
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -1.8489379724509827
# 500 | Counter({('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 21, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 21, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 19, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 18, ('Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 16, ('X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 14, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X'): 14, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'X', 'Z'): 13, ('Z', 'Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Z'): 13, ('Y', 'Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'Z'): 13, ('Z', 'X', 'X', 'Z', 'Y', 'Y', 'Z', 'Z'): 13, ('Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 13, ('X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 13, ('Y', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 13, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 13, ('Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 13, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 13, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z'): 13, ('Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 13, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 13, ('X', 'X', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 13, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 13, ('Z', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 13, ('X', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z'): 13, ('Z', 'Z', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 13, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 13, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'Y', 'X'): 13, ('Y', 'X', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 13, ('X', 'Z', 'X', 'Z', 'X', 'X', 'X', 'Z'): 13, ('X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 13, ('Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Z'): 13, ('Y', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 13, ('Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 13, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 13, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 13, ('Z', 'Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z'): 13}) | 0.08737184300677447
# Original derandomized Hamiltonian Counter({('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 9, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 9, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 7, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 6, ('Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 4, ('X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 3, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X'): 3, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('Z', 'Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Z'): 1, ('Y', 'Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'X', 'Z', 'Y', 'Y', 'Z', 'Z'): 1, ('Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 1, ('Y', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 1, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z'): 1, ('Z', 'Z', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('Y', 'X', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('X', 'Z', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Z'): 1, ('Y', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z'): 1})
# Size-adjusted derandomized Hamiltonian Counter({('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 28, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 28, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 25, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 25, ('Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 23, ('X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 21, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X'): 21, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'X', 'Z'): 20, ('Z', 'Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Z'): 20, ('Y', 'Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'Z'): 20, ('Z', 'X', 'X', 'Z', 'Y', 'Y', 'Z', 'Z'): 20, ('Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 20, ('X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 20, ('Y', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 20, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 20, ('Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 20, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 20, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z'): 20, ('Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 20, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 20, ('X', 'X', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 20, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 20, ('Z', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 20, ('X', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z'): 20, ('Z', 'Z', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 20, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 20, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'Y', 'X'): 20, ('Y', 'X', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 20, ('X', 'Z', 'X', 'Z', 'X', 'X', 'X', 'Z'): 20, ('X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 20, ('Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Z'): 20, ('Y', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 20, ('Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 20, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 20, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 20, ('Z', 'Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z'): 19})
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -1.8728133054474998
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -1.8434769519646248
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -1.8372672119283742
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -1.8263686820375484
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -1.8877775595261852
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -1.819128246682145
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -1.869042729769351
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -1.792720863199317
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -1.850662392204093
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -1.863433182748905
# 750 | Counter({('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 28, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 28, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 25, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 25, ('Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 23, ('X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 21, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X'): 21, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'X', 'Z'): 20, ('Z', 'Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Z'): 20, ('Y', 'Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'Z'): 20, ('Z', 'X', 'X', 'Z', 'Y', 'Y', 'Z', 'Z'): 20, ('Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 20, ('X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 20, ('Y', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 20, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 20, ('Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 20, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 20, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z'): 20, ('Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 20, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 20, ('X', 'X', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 20, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 20, ('Z', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 20, ('X', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z'): 20, ('Z', 'Z', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 20, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 20, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'Y', 'X'): 20, ('Y', 'X', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 20, ('X', 'Z', 'X', 'Z', 'X', 'X', 'X', 'Z'): 20, ('X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 20, ('Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Z'): 20, ('Y', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 20, ('Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 20, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 20, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 20, ('Z', 'Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z'): 19}) | 0.037090472486779234
# Original derandomized Hamiltonian Counter({('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 9, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 9, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 7, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 6, ('Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 4, ('X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 3, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X'): 3, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('Z', 'Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Z'): 1, ('Y', 'Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'X', 'Z', 'Y', 'Y', 'Z', 'Z'): 1, ('Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 1, ('Y', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 1, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z'): 1, ('Z', 'Z', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('Y', 'X', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('X', 'Z', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Z'): 1, ('Y', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z'): 1})
# Size-adjusted derandomized Hamiltonian Counter({('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 35, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 35, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 32, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 32, ('Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 30, ('X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 28, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X'): 28, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'X', 'Z'): 27, ('Z', 'Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Z'): 27, ('Y', 'Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'Z'): 27, ('Z', 'X', 'X', 'Z', 'Y', 'Y', 'Z', 'Z'): 27, ('Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 27, ('X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 27, ('Y', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 27, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 27, ('Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 27, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 27, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z'): 27, ('Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 27, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 27, ('X', 'X', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 27, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 27, ('Z', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 27, ('X', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z'): 27, ('Z', 'Z', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 27, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 27, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'Y', 'X'): 27, ('Y', 'X', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 27, ('X', 'Z', 'X', 'Z', 'X', 'X', 'X', 'Z'): 27, ('X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 27, ('Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Z'): 27, ('Y', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 27, ('Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 27, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 26, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 26, ('Z', 'Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z'): 26})
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -1.862599480428851
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -1.8418023813932267
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -1.8580725932821585
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -1.8388496836952095
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -1.8301068598854358
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -1.7757121105364393
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -1.84179553634516
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -1.8205988006036455
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -1.8724586354153623
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -1.805927506133631
# 1000 | Counter({('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 35, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 35, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 32, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 32, ('Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 30, ('X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 28, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X'): 28, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'X', 'Z'): 27, ('Z', 'Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Z'): 27, ('Y', 'Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'Z'): 27, ('Z', 'X', 'X', 'Z', 'Y', 'Y', 'Z', 'Z'): 27, ('Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 27, ('X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 27, ('Y', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 27, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 27, ('Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 27, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 27, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z'): 27, ('Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 27, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 27, ('X', 'X', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 27, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 27, ('Z', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 27, ('X', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z'): 27, ('Z', 'Z', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 27, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 27, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'Y', 'X'): 27, ('Y', 'X', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 27, ('X', 'Z', 'X', 'Z', 'X', 'X', 'X', 'Z'): 27, ('X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 27, ('Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Z'): 27, ('Y', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 27, ('Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 27, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 26, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 26, ('Z', 'Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z'): 26}) | 0.04575078771026839
# Original derandomized Hamiltonian Counter({('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 9, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 9, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 7, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 6, ('Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 4, ('X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 3, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X'): 3, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('Z', 'Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Z'): 1, ('Y', 'Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'X', 'Z', 'Y', 'Y', 'Z', 'Z'): 1, ('Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 1, ('Y', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 1, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z'): 1, ('Z', 'Z', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('Y', 'X', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('X', 'Z', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Z'): 1, ('Y', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z'): 1})
# Size-adjusted derandomized Hamiltonian Counter({('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 42, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 42, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 39, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 39, ('Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 37, ('X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 35, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X'): 35, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'X', 'Z'): 34, ('Z', 'Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Z'): 34, ('Y', 'Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'Z'): 34, ('Z', 'X', 'X', 'Z', 'Y', 'Y', 'Z', 'Z'): 34, ('Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 34, ('X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 34, ('Y', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 34, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 34, ('Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 34, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 34, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z'): 34, ('Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 34, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 34, ('X', 'X', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 34, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 34, ('Z', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 34, ('X', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z'): 34, ('Z', 'Z', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 34, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 34, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'Y', 'X'): 34, ('Y', 'X', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 34, ('X', 'Z', 'X', 'Z', 'X', 'X', 'X', 'Z'): 34, ('X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 34, ('Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Z'): 34, ('Y', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 33, ('Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 33, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 33, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 33, ('Z', 'Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z'): 33})
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -1.8159919640217201
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -1.8820593060450237
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -1.8023689677520507
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -1.838754339800589
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -1.8016289673821635
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -1.7772965916589323
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -1.7926697342382671
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -1.8351950821771605
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -1.8523522925560683
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -1.864808672104897
# 1250 | Counter({('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 42, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 42, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 39, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 39, ('Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 37, ('X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 35, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X'): 35, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'X', 'Z'): 34, ('Z', 'Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Z'): 34, ('Y', 'Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'Z'): 34, ('Z', 'X', 'X', 'Z', 'Y', 'Y', 'Z', 'Z'): 34, ('Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 34, ('X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 34, ('Y', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 34, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 34, ('Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 34, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 34, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z'): 34, ('Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 34, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 34, ('X', 'X', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 34, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 34, ('Z', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 34, ('X', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z'): 34, ('Z', 'Z', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 34, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 34, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'Y', 'X'): 34, ('Y', 'X', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 34, ('X', 'Z', 'X', 'Z', 'X', 'X', 'X', 'Z'): 34, ('X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 34, ('Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Z'): 34, ('Y', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 33, ('Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 33, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 33, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 33, ('Z', 'Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z'): 33}) | 0.055515054593372394
# Original derandomized Hamiltonian Counter({('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 9, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 9, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 7, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 6, ('Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 4, ('X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 3, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X'): 3, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('Z', 'Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Z'): 1, ('Y', 'Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'X', 'Z', 'Y', 'Y', 'Z', 'Z'): 1, ('Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 1, ('Y', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 1, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z'): 1, ('Z', 'Z', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('Y', 'X', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('X', 'Z', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Z'): 1, ('Y', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z'): 1})
# Size-adjusted derandomized Hamiltonian Counter({('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 49, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 49, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 46, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 45, ('Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 44, ('X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 42, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X'): 42, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'X', 'Z'): 41, ('Z', 'Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Z'): 41, ('Y', 'Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'Z'): 41, ('Z', 'X', 'X', 'Z', 'Y', 'Y', 'Z', 'Z'): 41, ('Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 41, ('X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 41, ('Y', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 41, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 41, ('Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 41, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 41, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z'): 41, ('Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 41, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 41, ('X', 'X', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 41, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 41, ('Z', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 41, ('X', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z'): 41, ('Z', 'Z', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 41, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 41, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'Y', 'X'): 41, ('Y', 'X', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 41, ('X', 'Z', 'X', 'Z', 'X', 'X', 'X', 'Z'): 41, ('X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 41, ('Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Z'): 40, ('Y', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 40, ('Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 40, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 40, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 40, ('Z', 'Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z'): 40})
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -1.873227660803559
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -1.8811196495508453
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -1.8259893529248747
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -1.868502448237964
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -1.868087804692849
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -1.8551073410338523
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -1.807129975509731
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -1.852736332748087
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -1.8291156828647197
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -1.8331588057406862
# 1500 | Counter({('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 49, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 49, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 46, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 45, ('Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 44, ('X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 42, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X'): 42, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'X', 'Z'): 41, ('Z', 'Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Z'): 41, ('Y', 'Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'Z'): 41, ('Z', 'X', 'X', 'Z', 'Y', 'Y', 'Z', 'Z'): 41, ('Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 41, ('X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 41, ('Y', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 41, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 41, ('Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 41, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 41, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z'): 41, ('Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 41, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 41, ('X', 'X', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 41, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 41, ('Z', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 41, ('X', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z'): 41, ('Z', 'Z', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 41, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 41, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'Y', 'X'): 41, ('Y', 'X', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 41, ('X', 'Z', 'X', 'Z', 'X', 'X', 'X', 'Z'): 41, ('X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 41, ('Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Z'): 40, ('Y', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 40, ('Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 40, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 40, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 40, ('Z', 'Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z'): 40}) | 0.03202337853817699
# Original derandomized Hamiltonian Counter({('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 9, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 9, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 7, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 6, ('Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 4, ('X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 3, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X'): 3, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('Z', 'Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Z'): 1, ('Y', 'Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'X', 'Z', 'Y', 'Y', 'Z', 'Z'): 1, ('Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 1, ('Y', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 1, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('Z', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z'): 1, ('Z', 'Z', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'Y', 'X'): 1, ('Y', 'X', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('X', 'Z', 'X', 'Z', 'X', 'X', 'X', 'Z'): 1, ('X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 1, ('Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Z'): 1, ('Y', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 1, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z'): 1})
# Size-adjusted derandomized Hamiltonian Counter({('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 56, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 56, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 53, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 52, ('Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 50, ('X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 49, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X'): 49, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'X', 'Z'): 48, ('Z', 'Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Z'): 48, ('Y', 'Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'Z'): 48, ('Z', 'X', 'X', 'Z', 'Y', 'Y', 'Z', 'Z'): 48, ('Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 48, ('X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 48, ('Y', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 48, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 48, ('Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 48, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 48, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z'): 48, ('Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 48, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 48, ('X', 'X', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 48, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 48, ('Z', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 48, ('X', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z'): 48, ('Z', 'Z', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 48, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 48, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'Y', 'X'): 48, ('Y', 'X', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 48, ('X', 'Z', 'X', 'Z', 'X', 'X', 'X', 'Z'): 48, ('X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 47, ('Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Z'): 47, ('Y', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 47, ('Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 47, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 47, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 47, ('Z', 'Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z'): 47})
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -1.8049590646081095
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -1.8128172725250293
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -1.857047494035643
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -1.7978911693487614
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -1.8006202042043074
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -1.9071151600908245
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -1.8240916941635774
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -1.8327353006538416
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -1.8495873230876299
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -1.833586620417969
# 1750 | Counter({('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 56, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 56, ('X', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 53, ('Z', 'Z', 'Z', 'Z', 'X', 'Z', 'Z', 'Z'): 52, ('Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 50, ('X', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 49, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'X'): 49, ('X', 'Z', 'X', 'Z', 'X', 'Z', 'X', 'Z'): 48, ('Z', 'Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Z'): 48, ('Y', 'Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'Z'): 48, ('Z', 'X', 'X', 'Z', 'Y', 'Y', 'Z', 'Z'): 48, ('Y', 'Y', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 48, ('X', 'X', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 48, ('Y', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 48, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'X', 'X'): 48, ('Z', 'Z', 'Z', 'Z', 'Y', 'Y', 'Y', 'X'): 48, ('Z', 'X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 48, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Z', 'Z'): 48, ('Y', 'Y', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 48, ('Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z', 'Z'): 48, ('X', 'X', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 48, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 48, ('Z', 'Z', 'X', 'Z', 'X', 'X', 'Z', 'Z'): 48, ('X', 'X', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z'): 48, ('Z', 'Z', 'X', 'Z', 'Y', 'X', 'Y', 'X'): 48, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z'): 48, ('Y', 'X', 'Y', 'Z', 'Y', 'X', 'Y', 'X'): 48, ('Y', 'X', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 48, ('X', 'Z', 'X', 'Z', 'X', 'X', 'X', 'Z'): 48, ('X', 'X', 'X', 'Z', 'Z', 'Z', 'X', 'Z'): 47, ('Y', 'X', 'Y', 'Z', 'X', 'X', 'X', 'Z'): 47, ('Y', 'Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 47, ('Z', 'Z', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 47, ('X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 47, ('X', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 47, ('Z', 'Y', 'Y', 'X', 'Z', 'Z', 'Z', 'Z'): 47}) | 0.050521737916430755
# Execution time =  00:28:28

# %%
import matplotlib.pyplot as plt 
points = [50, 250, 500, 750, 1000, 1250, 1500, 1750] 
num_points = len(points)
rmse_errors = [0.24904015355234405, 0.09229001113378285, 0.08737184300677447, 0.037090472486779234, 
              0.04575078771026839, 0.055515054593372394, 0.03202337853817699, 0.050521737916430755]

plt.plot([i for i in points], [rmse_errors[i] for i in range(num_points)], 'r', label='derandomized classical shadow')
plt.xlabel('Number of measurements')
plt.ylabel('Average RMSE error')
plt.legend(loc=1)
