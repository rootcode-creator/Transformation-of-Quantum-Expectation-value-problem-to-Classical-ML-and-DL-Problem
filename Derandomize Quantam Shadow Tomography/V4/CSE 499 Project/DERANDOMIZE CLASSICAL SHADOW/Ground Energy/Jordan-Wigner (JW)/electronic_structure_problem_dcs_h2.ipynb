# %%
import warnings
warnings.filterwarnings('ignore')

# %%
'''


Electronic structure problem with classical shadows, as presented in https://arxiv.org/abs/2103.07510
This code uses Qiskit as platform. 
The shadow is constructed based on derandomized Hamiltonian.
The molecules tested are: H2 (6-31s basis), LiH (sto3g basis), BeH2 (sto3g), H2O (sto3g), and NH3 (sto3g).
The coordinates for NH3 were taken from 'Algorithms for Computer Detection of Symmetry Elementsin Molecular Systems'. 
'''

import time
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit, execute
from qiskit_aer.primitives import Estimator as AerEstimator 
from qiskit_aer import QasmSimulator

from qiskit.quantum_info import SparsePauliOp

from qiskit_nature.units import DistanceUnit
from qiskit_nature.second_q.drivers import PySCFDriver
from qiskit_nature.second_q.algorithms import GroundStateEigensolver
from qiskit_nature.second_q.mappers import BravyiKitaevMapper, JordanWignerMapper, ParityMapper

from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock
from qiskit_nature.second_q.algorithms import VQEUCCFactory
from qiskit.algorithms.minimum_eigensolvers import VQE
from qiskit.algorithms.optimizers import SLSQP, COBYLA, SPSA

# Estimator primitive is based on the Statevector construct = algebraic simulation
from qiskit.primitives import Estimator 
from qiskit.utils import algorithm_globals

from modified_derandomization import modified_derandomized_classical_shadow
from data_acquisition_shadow import derandomized_classical_shadow
from prediction_shadow import estimate_exp

import qiskit_nature
qiskit_nature.settings.use_pauli_sum_op = False
import h5py
H5PY_DEFAULT_READONLY=1

# %%
'''
DEFINING DRIVERS FOR THE MOLECULES
'''


H2_driver = PySCFDriver(
    atom="H 0 0 0; H 0 0 0.735",
    basis="6-31g",
    charge=0,
    spin=0,
    unit=DistanceUnit.ANGSTROM,
)

LiH_driver = PySCFDriver(
    atom="Li 0 0 0; H 0 0 1.599",
    basis="sto3g",
    charge=0,
    spin=0,
    unit=DistanceUnit.ANGSTROM,
)

BeH2_driver = PySCFDriver(
    atom="Be 0 0 0; H 0 0 1.3264; H 0 0 -1.3264",
    basis="sto3g",
    charge=0,
    spin=0,
    unit=DistanceUnit.ANGSTROM,
)

H2O_driver = PySCFDriver(
    atom="O 0.0 0.0 0.0; H 0.757 0.586 0.0; H -0.757 0.586 0.0",
    basis="sto3g",
    charge=0,
    spin=0,
    unit=DistanceUnit.ANGSTROM,
)

NH3_driver = PySCFDriver(
    atom="N 0 0 0; H 0 0 1.008000; H 0.950353 0 -0.336000; H -0.475176 -0.823029 -0.336000",
    basis="sto3g",
    charge=0,
    spin=0,
    unit=DistanceUnit.ANGSTROM,
)

# %%
'''
FORMATTING HAMILTONIAN
'''

def process_hamiltonian(hamiltonian, derandomize = False):

    hamiltonian_observables = []
    hamiltonian_coefficients = []

    for observable in hamiltonian.paulis:
        op_list = []
        for op_index, pauli_op in enumerate(observable):
            pauli_op = str(pauli_op)
            if pauli_op == 'I' or pauli_op == 'X' or pauli_op == 'Y' or pauli_op == 'Z':
                op_list.append((pauli_op, op_index))
        hamiltonian_observables.append(op_list)
    
    hamiltonian_coefficients = hamiltonian.coeffs.real
    
    system_size = len(hamiltonian_observables[0])

    # removing all occurrences of Pauli-I, for all-Pauli-I there is an empty list left
    # these observables are needed for estimate_exp()
    observables_xyze = []

    for observable in hamiltonian_observables:
        XYZE = []
        for pauli in observable:
            if pauli[0] != 'I':
                XYZE.append(pauli)
        observables_xyze.append(XYZE)   
    
    # derandomisation procedure requires that coefficients are non-negative
    if derandomize == True:
        absolute_coefficients = [abs(coeffcient) for coeffcient in hamiltonian_coefficients]

        # removing the empty list as well
        # these observables are needed for derandomisation procedure
        observables_xyz = []
        for idx, observable in enumerate(observables_xyze):
            if observable:
                observables_xyz.append(observable)
            else:
                absolute_coefficients.pop(idx)
        
        return system_size, observables_xyze, observables_xyz, hamiltonian_coefficients, absolute_coefficients
    
    return system_size, observables_xyze, hamiltonian_coefficients








'''
COST FUNCTION AND HELPER FUNCTIONS
''' 

def basis_change_circuit(pauli_op):

    #   Generating circuit with just the basis change operators
    #
    #       pauli_op: n-qubit Pauli operator

    basis_change = QuantumCircuit(ansatz.num_qubits, ansatz.num_qubits)

    for idx, op in enumerate(pauli_op):
        
        if op == 'X':
            basis_change.h(idx)
        if op == 'Y':
            basis_change.h(idx)
            basis_change.p(-np.pi/2, idx)
            
    return basis_change

    
    


def ground_state_energy_from_shadow(operators, params):
    
    backend = QasmSimulator(method='statevector', shots=1)
    
    pauli_op_dict = Counter(tuple(x) for x in operators)    
    

    shadow = []
    for pauli_op in pauli_op_dict:
        
        qc = ansatz.bind_parameters(params)
        qc = qc.compose(basis_change_circuit(pauli_op))                                  
        qc.measure(reversed(range(system_size)), range(system_size))                      
        
        result = execute(qc, backend, shots=pauli_op_dict[pauli_op]).result()
        counts = result.get_counts()    # given in order q0 q1 ... qn-1 after register reversal in qc.measure
        
        for count in counts:
            for _ in range(counts[count]): # number of repeated measurement values

                output_str = list(count)   
                output = [int(i) for i in output_str]
                eigenvals = [x+1 if x == 0 else x-2 for x in output]
                snapshot = [(op, eigenval) for op, eigenval in zip(pauli_op, eigenvals)]
                
                shadow.append(snapshot)
    

    expectation_value = 0.0
    for term, weight in zip(observables_xyze, hamiltonian_coefficients):
        
        sum_product, match_count = estimate_exp(shadow, term)
        
        if match_count != 0:
            expectation_value += (weight * sum_product / match_count)

    return expectation_value

# %%
'''
EXPERIMENTS
'''

start_time = time.time()
all_molecules_rmse_errors = []



# CALCULATING FERMIONIC HAMILTONIAN AND CONVERTING TO QUBIT HAMILTONIAN

MOLECULES = ['H2']

for molecule in MOLECULES:   
    
    rmse_errors = []
    
    if molecule == 'H2':
        problem = H2_driver.run()
    if molecule == 'LiH':
        problem = LiH_driver.run()
    if molecule == 'BeH2':
        problem = BeH2_driver.run()
    if molecule == 'H2O':
        problem = H2O_driver.run()
    if molecule == 'NH3':
        problem = NH3_driver.run()

    hamiltonian = problem.hamiltonian
    second_q_op = hamiltonian.second_q_op()

    jw_mapper = JordanWignerMapper() #(num_particles=problem.num_particles)  #JordanWignerMapper()
    bkencoded_hamiltonian = jw_mapper.map(second_q_op)
    #print('Qubit Hamiltonian in Bravyi-Kitaev encoding', bkencoded_hamiltonian)


    # process the Hamiltonian to obtain properly formatted data
    hamiltonian_data = process_hamiltonian(bkencoded_hamiltonian, derandomize = True)
    system_size, observables_xyze, observables_xyz, hamiltonian_coefficients, absolute_coefficients = hamiltonian_data

    '''
    VARIATIONAL ANSATZ
    '''
    ansatz = UCCSD(
        problem.num_spatial_orbitals,
        problem.num_particles,
        jw_mapper,
        initial_state=HartreeFock(
            problem.num_spatial_orbitals,
            problem.num_particles,
            jw_mapper,
        ),
    )
    
    '''
    Running VQE on the Hamiltonian obtained from PySCFDriver using Statevector simulator (Estimator primitive)
    '''
    #estimator = Estimator()
    # If shots = None, it calculates the exact expectation values. Otherwise, it samples from normal distributions 
    # with standard errors as standard deviations using normal distribution approximation.
    #estimator.set_options(shots = None)
    #estimator = AerEstimator()
    #estimator.set_options(approximation=False, shots=None)
    
    #vqe_solver = VQE(estimator, ansatz, SLSQP())
    vqe_solver = VQE(Estimator(), ansatz, SLSQP())
    vqe_solver.initial_point = np.zeros(ansatz.num_parameters)

    calc = GroundStateEigensolver(jw_mapper, vqe_solver)
    result = calc.solve(problem)
    print(result.raw_result)
    


    #print('NUMBER OF OPERATORS | DERANDOMISED OPERATORS | AVERAGE RMSE ERROR\n')
    measurement_range = [50, 250, 500, 750, 1000, 1250, 1500, 1750]   

    for num_operators in measurement_range:   

        derandomized_hamiltonian = derandomized_classical_shadow(observables_xyz, 50, 
                                                                          system_size, weight=absolute_coefficients)

        tuples = (tuple(pauli) for pauli in derandomized_hamiltonian)
        counts = Counter(tuples)
        print('Original derandomized Hamiltonian', counts)
        
        # derandomized classical shadow will usually either undergenerate or overgenerate derandomized operators
        # adjusting for this issue: 
        
        while sum(counts.values()) != num_operators:
            for key, value in zip(counts.keys(), counts.values()):
                sum_counts = sum(counts.values())
                if sum_counts == num_operators:
                    break
                if sum_counts < num_operators:
                    # generate additional operators from the existing ones by increasing the number of counts
                    counts[key] += 1
                if sum_counts > num_operators:
                    # remove the element with highest count
                    max_element_key = [k for k, v in counts.items() if v == max(counts.values())][0]
                    counts[max_element_key] -= 1
    
        print('Size-adjusted derandomized Hamiltonian', counts)
        
        # translate the Counter to a set of derandomized operators
        new_derandomized_hamiltonian = []
        for key, value in counts.items():
            for _ in range(value):
                new_derandomized_hamiltonian.append(list(key))
        #print('Size-adjusted derandomized Hamiltonian', new_derandomized_hamiltonian)
        
        
        expectation_values = []
        num_experiments = 10   

        
        for iteration in range(num_experiments):

            expectation_value = ground_state_energy_from_shadow(new_derandomized_hamiltonian, result.raw_result.optimal_point)
            expectation_values.append(expectation_value)

            print("EXPERIMENT {}: GROUND STATE ENERGY FOUND = {}".format(iteration, expectation_value))


        rmse_derandomised_cs = np.sqrt(np.sum([(expectation_values[i] - result.raw_result.optimal_value)**2 
                                               for i in range(num_experiments)])/num_experiments)

        rmse_errors.append(rmse_derandomised_cs)

        print('{} | {} | {}'.format(num_operators, counts, rmse_derandomised_cs))
        
    all_molecules_rmse_errors.append(rmse_errors)
    
    elapsed_time = time.time() - start_time
    print("Execution time = ", time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# {   'aux_operators_evaluated': {   'AngularMomentum': (   5.825094573363998e-11,
#                                                           {}),
#                                    'Magnetization': (0.0, {}),
#                                    'ParticleNumber': (2.0000000000000004, {}),
#                                    'XDipole': (0.0, {}),
#                                    'YDipole': (0.0, {}),
#                                    'ZDipole': (1.3889498746739455, {})},
#     'cost_function_evals': 116,
#     'eigenvalue': -1.8715832252331936,
#     'optimal_circuit': <qiskit_nature.second_q.circuit.library.ansatzes.uccsd.UCCSD object at 0x7f601966a790>,
#     'optimal_parameters': {   ParameterVectorElement(t[0]): 5.312152396267837e-07,
#                               ParameterVectorElement(t[1]): -0.005517571901245214,
#                               ParameterVectorElement(t[2]): -2.440536061239092e-08,
#                               ParameterVectorElement(t[3]): 2.493186850018982e-07,
#                               ParameterVectorElement(t[4]): -0.005518661003770721,
#                               ParameterVectorElement(t[5]): 1.4591491778060683e-07,
#                               ParameterVectorElement(t[6]): -0.0757402355162404,
#                               ParameterVectorElement(t[7]): 9.657472005074348e-07,
#                               ParameterVectorElement(t[8]): 0.04521455470463956,
#                               ParameterVectorElement(t[9]): -2.390662717649163e-07,
#                               ParameterVectorElement(t[10]): -0.05117780362450096,
#                               ParameterVectorElement(t[11]): 8.036825201816042e-07,
#                               ParameterVectorElement(t[12]): 0.04532761888657165,
#                               ParameterVectorElement(t[13]): 2.0742130582034628e-07,
#                               ParameterVectorElement(t[14]): -0.04320010544163433},
#     'optimal_point': array([ 5.31215240e-07, -5.51757190e-03, -2.44053606e-08,  2.49318685e-07,
#        -5.51866100e-03,  1.45914918e-07, -7.57402355e-02,  9.65747201e-07,
#         4.52145547e-02, -2.39066272e-07, -5.11778036e-02,  8.03682520e-07,
#         4.53276189e-02,  2.07421306e-07, -4.32001054e-02]),
#     'optimal_value': -1.8715832252331936,
#     'optimizer_evals': None,
#     'optimizer_result': <qiskit.algorithms.optimizers.optimizer.OptimizerResult object at 0x7f6014c47290>,
#     'optimizer_time': 19.216680765151978}
# Original derandomized Hamiltonian Counter({('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 24, ('X', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 5, ('Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 4, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'X', 'Z'): 2, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 2, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'X'): 1, ('X', 'Z', 'X', 'X', 'X', 'Z', 'X', 'Z'): 1, ('Y', 'Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y'): 1, ('Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y', 'Z'): 1, ('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z'): 1, ('Y', 'Z', 'Y', 'Y', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Y', 'Y', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'X', 'X'): 1, ('X', 'Z', 'X', 'X', 'Y', 'Z', 'Z', 'Y'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z', 'X'): 1, ('Z', 'X', 'X', 'X', 'Y', 'Y', 'Z', 'Y'): 1, ('Y', 'Y', 'X', 'X', 'X', 'Z', 'Y', 'Y'): 1, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z'): 1, ('Z', 'Z', 'X', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Z', 'Y', 'Y', 'Y', 'Z', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X'): 1, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'X', 'X'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'X', 'X'): 1, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'Y'): 1, ('X', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'X'): 1, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y'): 1, ('Y', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z'): 1, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Z', 'Z'): 1, ('X', 'Y', 'Z', 'Z', 'Z', 'Y', 'Z', 'Y'): 1, ('X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'Y', 'Z', 'Y', 'X', 'X', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'Z'): 1})
# Size-adjusted derandomized Hamiltonian Counter({('Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 2, ('X', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 2, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 2, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 2, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'X'): 1, ('X', 'Z', 'X', 'X', 'X', 'Z', 'X', 'Z'): 1, ('Y', 'Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y'): 1, ('Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y', 'Z'): 1, ('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z'): 1, ('Y', 'Z', 'Y', 'Y', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Y', 'Y', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'X', 'X'): 1, ('X', 'Z', 'X', 'X', 'Y', 'Z', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z', 'X'): 1, ('Z', 'X', 'X', 'X', 'Y', 'Y', 'Z', 'Y'): 1, ('Y', 'Y', 'X', 'X', 'X', 'Z', 'Y', 'Y'): 1, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z'): 1, ('Z', 'Z', 'X', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Z', 'Y', 'Y', 'Y', 'Z', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X'): 1, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'X', 'X'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'X', 'X'): 1, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'Y'): 1, ('X', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'X'): 1, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y'): 1, ('Y', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z'): 1, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Z', 'Z'): 1, ('X', 'Y', 'Z', 'Z', 'Z', 'Y', 'Z', 'Y'): 1, ('X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'Y', 'Z', 'Y', 'X', 'X', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'Z'): 1})
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -1.9146732627024483
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -1.9272980559204784
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -1.9126789203493568
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -2.021792443989823
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -1.8522944805468513
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -1.629706603954222
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -1.8502656951706613
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -1.9098995756883013
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -1.6118960659094694
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -1.6492805931366499
# 50 | Counter({('Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 2, ('X', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 2, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 2, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 2, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'X'): 1, ('X', 'Z', 'X', 'X', 'X', 'Z', 'X', 'Z'): 1, ('Y', 'Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y'): 1, ('Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y', 'Z'): 1, ('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z'): 1, ('Y', 'Z', 'Y', 'Y', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Y', 'Y', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'X', 'X'): 1, ('X', 'Z', 'X', 'X', 'Y', 'Z', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z', 'X'): 1, ('Z', 'X', 'X', 'X', 'Y', 'Y', 'Z', 'Y'): 1, ('Y', 'Y', 'X', 'X', 'X', 'Z', 'Y', 'Y'): 1, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z'): 1, ('Z', 'Z', 'X', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Z', 'Y', 'Y', 'Y', 'Z', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X'): 1, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'X', 'X'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'X', 'X'): 1, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'Y'): 1, ('X', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'X'): 1, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y'): 1, ('Y', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z'): 1, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Z', 'Z'): 1, ('X', 'Y', 'Z', 'Z', 'Z', 'Y', 'Z', 'Y'): 1, ('X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'Y', 'Z', 'Y', 'X', 'X', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'Z'): 1}) | 0.14382884814664976
# Original derandomized Hamiltonian Counter({('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 24, ('X', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 5, ('Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 4, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'X', 'Z'): 2, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 2, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'X'): 1, ('X', 'Z', 'X', 'X', 'X', 'Z', 'X', 'Z'): 1, ('Y', 'Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y'): 1, ('Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y', 'Z'): 1, ('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z'): 1, ('Y', 'Z', 'Y', 'Y', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Y', 'Y', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'X', 'X'): 1, ('X', 'Z', 'X', 'X', 'Y', 'Z', 'Z', 'Y'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z', 'X'): 1, ('Z', 'X', 'X', 'X', 'Y', 'Y', 'Z', 'Y'): 1, ('Y', 'Y', 'X', 'X', 'X', 'Z', 'Y', 'Y'): 1, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z'): 1, ('Z', 'Z', 'X', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Z', 'Y', 'Y', 'Y', 'Z', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X'): 1, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'X', 'X'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'X', 'X'): 1, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'Y'): 1, ('X', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'X'): 1, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y'): 1, ('Y', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z'): 1, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Z', 'Z'): 1, ('X', 'Y', 'Z', 'Z', 'Z', 'Y', 'Z', 'Y'): 1, ('X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'Y', 'Z', 'Y', 'X', 'X', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'Z'): 1})
# Size-adjusted derandomized Hamiltonian Counter({('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 27, ('Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 8, ('X', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 8, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'X', 'Z'): 6, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 5, ('X', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'X'): 5, ('X', 'Z', 'X', 'X', 'X', 'Z', 'X', 'Z'): 5, ('Y', 'Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y'): 5, ('Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y', 'Z'): 5, ('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 5, ('Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z'): 5, ('Y', 'Z', 'Y', 'Y', 'X', 'Z', 'Z', 'X'): 5, ('Z', 'X', 'Y', 'Y', 'Y', 'Z', 'Y', 'Y'): 5, ('Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'X', 'X'): 5, ('X', 'Z', 'X', 'X', 'Y', 'Z', 'Z', 'Y'): 5, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y'): 5, ('Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z'): 5, ('Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z', 'X'): 5, ('Z', 'X', 'X', 'X', 'Y', 'Y', 'Z', 'Y'): 5, ('Y', 'Y', 'X', 'X', 'X', 'Z', 'Y', 'Y'): 5, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y'): 5, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z'): 5, ('Z', 'Z', 'X', 'X', 'X', 'Z', 'Z', 'X'): 5, ('Z', 'Z', 'Y', 'Y', 'Y', 'Z', 'Z', 'Y'): 5, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X'): 5, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'X', 'X'): 5, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'X', 'X'): 5, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Y', 'Y'): 5, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'Y'): 5, ('X', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z'): 5, ('Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 5, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 5, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'X'): 5, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y'): 5, ('Y', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'Y'): 5, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 5, ('Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z'): 5, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Z'): 5, ('Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Z', 'Z'): 5, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 5, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X'): 5, ('X', 'Y', 'Z', 'Z', 'Z', 'Y', 'Z', 'Y'): 4, ('X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 4, ('X', 'Y', 'Z', 'Y', 'X', 'X', 'Z', 'Z'): 4, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'Z'): 4})
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -1.8464677623992167
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -1.6552165150248752
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -1.921387117163945
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -1.8097442173097107
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -1.9120041827808265
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -1.8668101592900235
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -1.7938255215573704
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -1.8154459408299044
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -1.9674916663137614
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -1.840069495171266
# 250 | Counter({('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 27, ('Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 8, ('X', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 8, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'X', 'Z'): 6, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 5, ('X', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'X'): 5, ('X', 'Z', 'X', 'X', 'X', 'Z', 'X', 'Z'): 5, ('Y', 'Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y'): 5, ('Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y', 'Z'): 5, ('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 5, ('Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z'): 5, ('Y', 'Z', 'Y', 'Y', 'X', 'Z', 'Z', 'X'): 5, ('Z', 'X', 'Y', 'Y', 'Y', 'Z', 'Y', 'Y'): 5, ('Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'X', 'X'): 5, ('X', 'Z', 'X', 'X', 'Y', 'Z', 'Z', 'Y'): 5, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y'): 5, ('Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z'): 5, ('Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z', 'X'): 5, ('Z', 'X', 'X', 'X', 'Y', 'Y', 'Z', 'Y'): 5, ('Y', 'Y', 'X', 'X', 'X', 'Z', 'Y', 'Y'): 5, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y'): 5, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z'): 5, ('Z', 'Z', 'X', 'X', 'X', 'Z', 'Z', 'X'): 5, ('Z', 'Z', 'Y', 'Y', 'Y', 'Z', 'Z', 'Y'): 5, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X'): 5, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'X', 'X'): 5, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'X', 'X'): 5, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Y', 'Y'): 5, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'Y'): 5, ('X', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z'): 5, ('Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 5, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 5, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'X'): 5, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y'): 5, ('Y', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'Y'): 5, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 5, ('Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z'): 5, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Z'): 5, ('Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Z', 'Z'): 5, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 5, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X'): 5, ('X', 'Y', 'Z', 'Z', 'Z', 'Y', 'Z', 'Y'): 4, ('X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 4, ('X', 'Y', 'Z', 'Y', 'X', 'X', 'Z', 'Z'): 4, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'Z'): 4}) | 0.08648448746089957
# Original derandomized Hamiltonian Counter({('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 24, ('X', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 5, ('Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 4, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'X', 'Z'): 2, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 2, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'X'): 1, ('X', 'Z', 'X', 'X', 'X', 'Z', 'X', 'Z'): 1, ('Y', 'Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y'): 1, ('Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y', 'Z'): 1, ('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z'): 1, ('Y', 'Z', 'Y', 'Y', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Y', 'Y', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'X', 'X'): 1, ('X', 'Z', 'X', 'X', 'Y', 'Z', 'Z', 'Y'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z', 'X'): 1, ('Z', 'X', 'X', 'X', 'Y', 'Y', 'Z', 'Y'): 1, ('Y', 'Y', 'X', 'X', 'X', 'Z', 'Y', 'Y'): 1, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z'): 1, ('Z', 'Z', 'X', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Z', 'Y', 'Y', 'Y', 'Z', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X'): 1, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'X', 'X'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'X', 'X'): 1, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'Y'): 1, ('X', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'X'): 1, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y'): 1, ('Y', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z'): 1, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Z', 'Z'): 1, ('X', 'Y', 'Z', 'Z', 'Z', 'Y', 'Z', 'Y'): 1, ('X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'Y', 'Z', 'Y', 'X', 'X', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'Z'): 1})
# Size-adjusted derandomized Hamiltonian Counter({('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 33, ('X', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 14, ('Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 13, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'X', 'Z'): 12, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 11, ('X', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'X'): 11, ('X', 'Z', 'X', 'X', 'X', 'Z', 'X', 'Z'): 11, ('Y', 'Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y'): 11, ('Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y', 'Z'): 11, ('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 11, ('Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z'): 11, ('Y', 'Z', 'Y', 'Y', 'X', 'Z', 'Z', 'X'): 11, ('Z', 'X', 'Y', 'Y', 'Y', 'Z', 'Y', 'Y'): 11, ('Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'X', 'X'): 11, ('X', 'Z', 'X', 'X', 'Y', 'Z', 'Z', 'Y'): 11, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y'): 11, ('Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z'): 11, ('Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z', 'X'): 11, ('Z', 'X', 'X', 'X', 'Y', 'Y', 'Z', 'Y'): 11, ('Y', 'Y', 'X', 'X', 'X', 'Z', 'Y', 'Y'): 11, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 11, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X'): 11, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y'): 10, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z'): 10, ('Z', 'Z', 'X', 'X', 'X', 'Z', 'Z', 'X'): 10, ('Z', 'Z', 'Y', 'Y', 'Y', 'Z', 'Z', 'Y'): 10, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X'): 10, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'X', 'X'): 10, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'X', 'X'): 10, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Y', 'Y'): 10, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'Y'): 10, ('X', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z'): 10, ('Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 10, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 10, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'X'): 10, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y'): 10, ('Y', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'Y'): 10, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 10, ('Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z'): 10, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Z'): 10, ('Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Z', 'Z'): 10, ('X', 'Y', 'Z', 'Z', 'Z', 'Y', 'Z', 'Y'): 10, ('X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 10, ('X', 'Y', 'Z', 'Y', 'X', 'X', 'Z', 'Z'): 10, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'Z'): 10})
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -1.7965487268988567
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -1.7853733313845224
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -1.8833497908857098
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -1.8390870423781929
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -1.9019225227137122
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -1.9214947287332063
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -1.8612923141946967
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -1.8731272735385354
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -1.99564363833681
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -1.8922441522337528
# 500 | Counter({('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 33, ('X', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 14, ('Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 13, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'X', 'Z'): 12, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 11, ('X', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'X'): 11, ('X', 'Z', 'X', 'X', 'X', 'Z', 'X', 'Z'): 11, ('Y', 'Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y'): 11, ('Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y', 'Z'): 11, ('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 11, ('Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z'): 11, ('Y', 'Z', 'Y', 'Y', 'X', 'Z', 'Z', 'X'): 11, ('Z', 'X', 'Y', 'Y', 'Y', 'Z', 'Y', 'Y'): 11, ('Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'X', 'X'): 11, ('X', 'Z', 'X', 'X', 'Y', 'Z', 'Z', 'Y'): 11, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y'): 11, ('Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z'): 11, ('Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z', 'X'): 11, ('Z', 'X', 'X', 'X', 'Y', 'Y', 'Z', 'Y'): 11, ('Y', 'Y', 'X', 'X', 'X', 'Z', 'Y', 'Y'): 11, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 11, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X'): 11, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y'): 10, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z'): 10, ('Z', 'Z', 'X', 'X', 'X', 'Z', 'Z', 'X'): 10, ('Z', 'Z', 'Y', 'Y', 'Y', 'Z', 'Z', 'Y'): 10, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X'): 10, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'X', 'X'): 10, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'X', 'X'): 10, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Y', 'Y'): 10, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'Y'): 10, ('X', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z'): 10, ('Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 10, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 10, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'X'): 10, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y'): 10, ('Y', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'Y'): 10, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 10, ('Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z'): 10, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Z'): 10, ('Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Z', 'Z'): 10, ('X', 'Y', 'Z', 'Z', 'Z', 'Y', 'Z', 'Y'): 10, ('X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 10, ('X', 'Y', 'Z', 'Y', 'X', 'X', 'Z', 'Z'): 10, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'Z'): 10}) | 0.05796080899837615
# Original derandomized Hamiltonian Counter({('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 24, ('X', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 5, ('Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 4, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'X', 'Z'): 2, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 2, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'X'): 1, ('X', 'Z', 'X', 'X', 'X', 'Z', 'X', 'Z'): 1, ('Y', 'Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y'): 1, ('Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y', 'Z'): 1, ('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z'): 1, ('Y', 'Z', 'Y', 'Y', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Y', 'Y', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'X', 'X'): 1, ('X', 'Z', 'X', 'X', 'Y', 'Z', 'Z', 'Y'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z', 'X'): 1, ('Z', 'X', 'X', 'X', 'Y', 'Y', 'Z', 'Y'): 1, ('Y', 'Y', 'X', 'X', 'X', 'Z', 'Y', 'Y'): 1, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z'): 1, ('Z', 'Z', 'X', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Z', 'Y', 'Y', 'Y', 'Z', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X'): 1, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'X', 'X'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'X', 'X'): 1, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'Y'): 1, ('X', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'X'): 1, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y'): 1, ('Y', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z'): 1, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Z', 'Z'): 1, ('X', 'Y', 'Z', 'Z', 'Z', 'Y', 'Z', 'Y'): 1, ('X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'Y', 'Z', 'Y', 'X', 'X', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'Z'): 1})
# Size-adjusted derandomized Hamiltonian Counter({('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 38, ('X', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 20, ('Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 19, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'X', 'Z'): 17, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 17, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 16, ('X', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'X'): 16, ('X', 'Z', 'X', 'X', 'X', 'Z', 'X', 'Z'): 16, ('Y', 'Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y'): 16, ('Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y', 'Z'): 16, ('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 16, ('Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z'): 16, ('Y', 'Z', 'Y', 'Y', 'X', 'Z', 'Z', 'X'): 16, ('Z', 'X', 'Y', 'Y', 'Y', 'Z', 'Y', 'Y'): 16, ('Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'X', 'X'): 16, ('X', 'Z', 'X', 'X', 'Y', 'Z', 'Z', 'Y'): 16, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y'): 16, ('Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z'): 16, ('Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z', 'X'): 16, ('Z', 'X', 'X', 'X', 'Y', 'Y', 'Z', 'Y'): 16, ('Y', 'Y', 'X', 'X', 'X', 'Z', 'Y', 'Y'): 16, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y'): 16, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z'): 16, ('Z', 'Z', 'X', 'X', 'X', 'Z', 'Z', 'X'): 16, ('Z', 'Z', 'Y', 'Y', 'Y', 'Z', 'Z', 'Y'): 16, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X'): 16, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'X', 'X'): 16, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'X', 'X'): 16, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Y', 'Y'): 16, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'Y'): 16, ('X', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z'): 16, ('Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 16, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 16, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'X'): 16, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y'): 16, ('Y', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'Y'): 16, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 16, ('Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z'): 16, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Z'): 16, ('Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Z', 'Z'): 16, ('X', 'Y', 'Z', 'Z', 'Z', 'Y', 'Z', 'Y'): 16, ('X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 16, ('X', 'Y', 'Z', 'Y', 'X', 'X', 'Z', 'Z'): 16, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X'): 16, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'Z'): 15})
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -1.8339090592730134
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -1.824620578743359
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -1.833586666501008
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -1.8886435936614878
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -1.8948107969491417
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -1.839854296880942
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -1.8512443701050454
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -1.8719403580136802
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -1.9485737990114926
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -1.9202590068582648
# 750 | Counter({('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 38, ('X', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 20, ('Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 19, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'X', 'Z'): 17, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 17, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 16, ('X', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'X'): 16, ('X', 'Z', 'X', 'X', 'X', 'Z', 'X', 'Z'): 16, ('Y', 'Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y'): 16, ('Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y', 'Z'): 16, ('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 16, ('Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z'): 16, ('Y', 'Z', 'Y', 'Y', 'X', 'Z', 'Z', 'X'): 16, ('Z', 'X', 'Y', 'Y', 'Y', 'Z', 'Y', 'Y'): 16, ('Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'X', 'X'): 16, ('X', 'Z', 'X', 'X', 'Y', 'Z', 'Z', 'Y'): 16, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y'): 16, ('Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z'): 16, ('Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z', 'X'): 16, ('Z', 'X', 'X', 'X', 'Y', 'Y', 'Z', 'Y'): 16, ('Y', 'Y', 'X', 'X', 'X', 'Z', 'Y', 'Y'): 16, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y'): 16, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z'): 16, ('Z', 'Z', 'X', 'X', 'X', 'Z', 'Z', 'X'): 16, ('Z', 'Z', 'Y', 'Y', 'Y', 'Z', 'Z', 'Y'): 16, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X'): 16, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'X', 'X'): 16, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'X', 'X'): 16, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Y', 'Y'): 16, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'Y'): 16, ('X', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z'): 16, ('Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 16, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 16, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'X'): 16, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y'): 16, ('Y', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'Y'): 16, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 16, ('Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z'): 16, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Z'): 16, ('Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Z', 'Z'): 16, ('X', 'Y', 'Z', 'Z', 'Z', 'Y', 'Z', 'Y'): 16, ('X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 16, ('X', 'Y', 'Z', 'Y', 'X', 'X', 'Z', 'Z'): 16, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X'): 16, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'Z'): 15}) | 0.03951777994016591
# Original derandomized Hamiltonian Counter({('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 24, ('X', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 5, ('Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 4, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'X', 'Z'): 2, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 2, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'X'): 1, ('X', 'Z', 'X', 'X', 'X', 'Z', 'X', 'Z'): 1, ('Y', 'Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y'): 1, ('Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y', 'Z'): 1, ('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z'): 1, ('Y', 'Z', 'Y', 'Y', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Y', 'Y', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'X', 'X'): 1, ('X', 'Z', 'X', 'X', 'Y', 'Z', 'Z', 'Y'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z', 'X'): 1, ('Z', 'X', 'X', 'X', 'Y', 'Y', 'Z', 'Y'): 1, ('Y', 'Y', 'X', 'X', 'X', 'Z', 'Y', 'Y'): 1, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z'): 1, ('Z', 'Z', 'X', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Z', 'Y', 'Y', 'Y', 'Z', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X'): 1, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'X', 'X'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'X', 'X'): 1, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'Y'): 1, ('X', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'X'): 1, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y'): 1, ('Y', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z'): 1, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Z', 'Z'): 1, ('X', 'Y', 'Z', 'Z', 'Z', 'Y', 'Z', 'Y'): 1, ('X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'Y', 'Z', 'Y', 'X', 'X', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'Z'): 1})
# Size-adjusted derandomized Hamiltonian Counter({('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 44, ('X', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 25, ('Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 24, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'X', 'Z'): 23, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 22, ('X', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'X'): 22, ('X', 'Z', 'X', 'X', 'X', 'Z', 'X', 'Z'): 22, ('Y', 'Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y'): 22, ('Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y', 'Z'): 22, ('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 22, ('Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z'): 22, ('Y', 'Z', 'Y', 'Y', 'X', 'Z', 'Z', 'X'): 22, ('Z', 'X', 'Y', 'Y', 'Y', 'Z', 'Y', 'Y'): 22, ('Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'X', 'X'): 22, ('X', 'Z', 'X', 'X', 'Y', 'Z', 'Z', 'Y'): 22, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y'): 22, ('Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z'): 22, ('Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z', 'X'): 22, ('Z', 'X', 'X', 'X', 'Y', 'Y', 'Z', 'Y'): 22, ('Y', 'Y', 'X', 'X', 'X', 'Z', 'Y', 'Y'): 22, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y'): 22, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z'): 22, ('Z', 'Z', 'X', 'X', 'X', 'Z', 'Z', 'X'): 22, ('Z', 'Z', 'Y', 'Y', 'Y', 'Z', 'Z', 'Y'): 22, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X'): 22, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 22, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X'): 22, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'X', 'X'): 21, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'X', 'X'): 21, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Y', 'Y'): 21, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'Y'): 21, ('X', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z'): 21, ('Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 21, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 21, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'X'): 21, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y'): 21, ('Y', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'Y'): 21, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 21, ('Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z'): 21, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Z'): 21, ('Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Z', 'Z'): 21, ('X', 'Y', 'Z', 'Z', 'Z', 'Y', 'Z', 'Y'): 21, ('X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 21, ('X', 'Y', 'Z', 'Y', 'X', 'X', 'Z', 'Z'): 21, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'Z'): 21})
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -1.8209880825654574
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -1.8062616264533435
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -1.9251861102045802
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -1.808472135295438
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -1.8630047796830773
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -1.7870588206591635
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -1.8258724430164892
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -1.8478375924764914
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -1.844761398610867
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -1.8546516094294951
# 1000 | Counter({('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 44, ('X', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 25, ('Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 24, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'X', 'Z'): 23, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 22, ('X', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'X'): 22, ('X', 'Z', 'X', 'X', 'X', 'Z', 'X', 'Z'): 22, ('Y', 'Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y'): 22, ('Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y', 'Z'): 22, ('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 22, ('Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z'): 22, ('Y', 'Z', 'Y', 'Y', 'X', 'Z', 'Z', 'X'): 22, ('Z', 'X', 'Y', 'Y', 'Y', 'Z', 'Y', 'Y'): 22, ('Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'X', 'X'): 22, ('X', 'Z', 'X', 'X', 'Y', 'Z', 'Z', 'Y'): 22, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y'): 22, ('Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z'): 22, ('Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z', 'X'): 22, ('Z', 'X', 'X', 'X', 'Y', 'Y', 'Z', 'Y'): 22, ('Y', 'Y', 'X', 'X', 'X', 'Z', 'Y', 'Y'): 22, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y'): 22, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z'): 22, ('Z', 'Z', 'X', 'X', 'X', 'Z', 'Z', 'X'): 22, ('Z', 'Z', 'Y', 'Y', 'Y', 'Z', 'Z', 'Y'): 22, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X'): 22, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 22, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X'): 22, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'X', 'X'): 21, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'X', 'X'): 21, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Y', 'Y'): 21, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'Y'): 21, ('X', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z'): 21, ('Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 21, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 21, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'X'): 21, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y'): 21, ('Y', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'Y'): 21, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 21, ('Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z'): 21, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Z'): 21, ('Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Z', 'Z'): 21, ('X', 'Y', 'Z', 'Z', 'Z', 'Y', 'Z', 'Y'): 21, ('X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 21, ('X', 'Y', 'Z', 'Y', 'X', 'X', 'Z', 'Z'): 21, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'Z'): 21}) | 0.049558494790220835
# Original derandomized Hamiltonian Counter({('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 24, ('X', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 5, ('Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 4, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'X', 'Z'): 2, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 2, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'X'): 1, ('X', 'Z', 'X', 'X', 'X', 'Z', 'X', 'Z'): 1, ('Y', 'Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y'): 1, ('Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y', 'Z'): 1, ('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z'): 1, ('Y', 'Z', 'Y', 'Y', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Y', 'Y', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'X', 'X'): 1, ('X', 'Z', 'X', 'X', 'Y', 'Z', 'Z', 'Y'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z', 'X'): 1, ('Z', 'X', 'X', 'X', 'Y', 'Y', 'Z', 'Y'): 1, ('Y', 'Y', 'X', 'X', 'X', 'Z', 'Y', 'Y'): 1, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z'): 1, ('Z', 'Z', 'X', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Z', 'Y', 'Y', 'Y', 'Z', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X'): 1, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'X', 'X'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'X', 'X'): 1, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'Y'): 1, ('X', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'X'): 1, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y'): 1, ('Y', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z'): 1, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Z', 'Z'): 1, ('X', 'Y', 'Z', 'Z', 'Z', 'Y', 'Z', 'Y'): 1, ('X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'Y', 'Z', 'Y', 'X', 'X', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'Z'): 1})
# Size-adjusted derandomized Hamiltonian Counter({('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 50, ('X', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 31, ('Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 30, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 28, ('X', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'X'): 28, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'X', 'Z'): 28, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 28, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X'): 28, ('X', 'Z', 'X', 'X', 'X', 'Z', 'X', 'Z'): 27, ('Y', 'Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y'): 27, ('Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y', 'Z'): 27, ('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 27, ('Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z'): 27, ('Y', 'Z', 'Y', 'Y', 'X', 'Z', 'Z', 'X'): 27, ('Z', 'X', 'Y', 'Y', 'Y', 'Z', 'Y', 'Y'): 27, ('Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'X', 'X'): 27, ('X', 'Z', 'X', 'X', 'Y', 'Z', 'Z', 'Y'): 27, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y'): 27, ('Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z'): 27, ('Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z', 'X'): 27, ('Z', 'X', 'X', 'X', 'Y', 'Y', 'Z', 'Y'): 27, ('Y', 'Y', 'X', 'X', 'X', 'Z', 'Y', 'Y'): 27, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y'): 27, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z'): 27, ('Z', 'Z', 'X', 'X', 'X', 'Z', 'Z', 'X'): 27, ('Z', 'Z', 'Y', 'Y', 'Y', 'Z', 'Z', 'Y'): 27, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X'): 27, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'X', 'X'): 27, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'X', 'X'): 27, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Y', 'Y'): 27, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'Y'): 27, ('X', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z'): 27, ('Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 27, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 27, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'X'): 27, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y'): 27, ('Y', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'Y'): 27, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 27, ('Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z'): 27, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Z'): 27, ('Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Z', 'Z'): 27, ('X', 'Y', 'Z', 'Z', 'Z', 'Y', 'Z', 'Y'): 27, ('X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 27, ('X', 'Y', 'Z', 'Y', 'X', 'X', 'Z', 'Z'): 27, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'Z'): 27})
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -1.8602959094460507
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -1.8417283972405727
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -1.857937016494984
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -1.900004790787146
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -1.7832293297617543
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -1.8140555000664373
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -1.8657059142942443
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -1.8612968083002777
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -1.8570802324255322
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -1.7810186957567002
# 1250 | Counter({('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 50, ('X', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 31, ('Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 30, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 28, ('X', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'X'): 28, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'X', 'Z'): 28, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 28, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X'): 28, ('X', 'Z', 'X', 'X', 'X', 'Z', 'X', 'Z'): 27, ('Y', 'Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y'): 27, ('Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y', 'Z'): 27, ('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 27, ('Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z'): 27, ('Y', 'Z', 'Y', 'Y', 'X', 'Z', 'Z', 'X'): 27, ('Z', 'X', 'Y', 'Y', 'Y', 'Z', 'Y', 'Y'): 27, ('Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'X', 'X'): 27, ('X', 'Z', 'X', 'X', 'Y', 'Z', 'Z', 'Y'): 27, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y'): 27, ('Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z'): 27, ('Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z', 'X'): 27, ('Z', 'X', 'X', 'X', 'Y', 'Y', 'Z', 'Y'): 27, ('Y', 'Y', 'X', 'X', 'X', 'Z', 'Y', 'Y'): 27, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y'): 27, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z'): 27, ('Z', 'Z', 'X', 'X', 'X', 'Z', 'Z', 'X'): 27, ('Z', 'Z', 'Y', 'Y', 'Y', 'Z', 'Z', 'Y'): 27, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X'): 27, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'X', 'X'): 27, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'X', 'X'): 27, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Y', 'Y'): 27, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'Y'): 27, ('X', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z'): 27, ('Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 27, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 27, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'X'): 27, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y'): 27, ('Y', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'Y'): 27, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 27, ('Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z'): 27, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Z'): 27, ('Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Z', 'Z'): 27, ('X', 'Y', 'Z', 'Z', 'Z', 'Y', 'Z', 'Y'): 27, ('X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 27, ('X', 'Y', 'Z', 'Y', 'X', 'X', 'Z', 'Z'): 27, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'Z'): 27}) | 0.046563067573260834
# Original derandomized Hamiltonian Counter({('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 24, ('X', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 5, ('Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 4, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'X', 'Z'): 2, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 2, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'X'): 1, ('X', 'Z', 'X', 'X', 'X', 'Z', 'X', 'Z'): 1, ('Y', 'Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y'): 1, ('Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y', 'Z'): 1, ('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z'): 1, ('Y', 'Z', 'Y', 'Y', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Y', 'Y', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'X', 'X'): 1, ('X', 'Z', 'X', 'X', 'Y', 'Z', 'Z', 'Y'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z', 'X'): 1, ('Z', 'X', 'X', 'X', 'Y', 'Y', 'Z', 'Y'): 1, ('Y', 'Y', 'X', 'X', 'X', 'Z', 'Y', 'Y'): 1, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z'): 1, ('Z', 'Z', 'X', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Z', 'Y', 'Y', 'Y', 'Z', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X'): 1, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'X', 'X'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'X', 'X'): 1, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'Y'): 1, ('X', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'X'): 1, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y'): 1, ('Y', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z'): 1, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Z', 'Z'): 1, ('X', 'Y', 'Z', 'Z', 'Z', 'Y', 'Z', 'Y'): 1, ('X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'Y', 'Z', 'Y', 'X', 'X', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'Z'): 1})
# Size-adjusted derandomized Hamiltonian Counter({('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 55, ('X', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 36, ('Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 35, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'X', 'Z'): 34, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 33, ('X', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'X'): 33, ('X', 'Z', 'X', 'X', 'X', 'Z', 'X', 'Z'): 33, ('Y', 'Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y'): 33, ('Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y', 'Z'): 33, ('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 33, ('Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z'): 33, ('Y', 'Z', 'Y', 'Y', 'X', 'Z', 'Z', 'X'): 33, ('Z', 'X', 'Y', 'Y', 'Y', 'Z', 'Y', 'Y'): 33, ('Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'X', 'X'): 33, ('X', 'Z', 'X', 'X', 'Y', 'Z', 'Z', 'Y'): 33, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y'): 33, ('Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z'): 33, ('Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z', 'X'): 33, ('Z', 'X', 'X', 'X', 'Y', 'Y', 'Z', 'Y'): 33, ('Y', 'Y', 'X', 'X', 'X', 'Z', 'Y', 'Y'): 33, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y'): 33, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z'): 33, ('Z', 'Z', 'X', 'X', 'X', 'Z', 'Z', 'X'): 33, ('Z', 'Z', 'Y', 'Y', 'Y', 'Z', 'Z', 'Y'): 33, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X'): 33, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'X', 'X'): 33, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'X', 'X'): 33, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Y', 'Y'): 33, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'Y'): 33, ('X', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z'): 33, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 33, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X'): 33, ('Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 32, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 32, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'X'): 32, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y'): 32, ('Y', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'Y'): 32, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 32, ('Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z'): 32, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Z'): 32, ('Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Z', 'Z'): 32, ('X', 'Y', 'Z', 'Z', 'Z', 'Y', 'Z', 'Y'): 32, ('X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 32, ('X', 'Y', 'Z', 'Y', 'X', 'X', 'Z', 'Z'): 32, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'Z'): 32})
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -1.7862187925960422
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -1.813688192535696
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -1.8334221794192407
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -1.8347217175873132
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -1.8830599472207965
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -1.877626047679817
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -1.8100932067246478
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -1.8989170245859086
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -1.9381901937912667
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -1.8568575905787252
# 1500 | Counter({('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 55, ('X', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 36, ('Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 35, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'X', 'Z'): 34, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 33, ('X', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'X'): 33, ('X', 'Z', 'X', 'X', 'X', 'Z', 'X', 'Z'): 33, ('Y', 'Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y'): 33, ('Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y', 'Z'): 33, ('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 33, ('Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z'): 33, ('Y', 'Z', 'Y', 'Y', 'X', 'Z', 'Z', 'X'): 33, ('Z', 'X', 'Y', 'Y', 'Y', 'Z', 'Y', 'Y'): 33, ('Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'X', 'X'): 33, ('X', 'Z', 'X', 'X', 'Y', 'Z', 'Z', 'Y'): 33, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y'): 33, ('Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z'): 33, ('Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z', 'X'): 33, ('Z', 'X', 'X', 'X', 'Y', 'Y', 'Z', 'Y'): 33, ('Y', 'Y', 'X', 'X', 'X', 'Z', 'Y', 'Y'): 33, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y'): 33, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z'): 33, ('Z', 'Z', 'X', 'X', 'X', 'Z', 'Z', 'X'): 33, ('Z', 'Z', 'Y', 'Y', 'Y', 'Z', 'Z', 'Y'): 33, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X'): 33, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'X', 'X'): 33, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'X', 'X'): 33, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Y', 'Y'): 33, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'Y'): 33, ('X', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z'): 33, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 33, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X'): 33, ('Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 32, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 32, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'X'): 32, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y'): 32, ('Y', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'Y'): 32, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 32, ('Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z'): 32, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Z'): 32, ('Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Z', 'Z'): 32, ('X', 'Y', 'Z', 'Z', 'Z', 'Y', 'Z', 'Y'): 32, ('X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 32, ('X', 'Y', 'Z', 'Y', 'X', 'X', 'Z', 'Z'): 32, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'Z'): 32}) | 0.0477531985572275
# Original derandomized Hamiltonian Counter({('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 24, ('X', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 5, ('Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 4, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'X', 'Z'): 2, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 2, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X'): 2, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'X'): 1, ('X', 'Z', 'X', 'X', 'X', 'Z', 'X', 'Z'): 1, ('Y', 'Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y'): 1, ('Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y', 'Z'): 1, ('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 1, ('Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z'): 1, ('Y', 'Z', 'Y', 'Y', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'X', 'Y', 'Y', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'X', 'X'): 1, ('X', 'Z', 'X', 'X', 'Y', 'Z', 'Z', 'Y'): 1, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z', 'X'): 1, ('Z', 'X', 'X', 'X', 'Y', 'Y', 'Z', 'Y'): 1, ('Y', 'Y', 'X', 'X', 'X', 'Z', 'Y', 'Y'): 1, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z'): 1, ('Z', 'Z', 'X', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Z', 'Z', 'Y', 'Y', 'Y', 'Z', 'Z', 'Y'): 1, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X'): 1, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'X', 'X'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'X', 'X'): 1, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Y', 'Y'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'Y'): 1, ('X', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 1, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 1, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'X'): 1, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y'): 1, ('Y', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'Y'): 1, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 1, ('Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z'): 1, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Z'): 1, ('Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Z', 'Z'): 1, ('X', 'Y', 'Z', 'Z', 'Z', 'Y', 'Z', 'Y'): 1, ('X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 1, ('X', 'Y', 'Z', 'Y', 'X', 'X', 'Z', 'Z'): 1, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'Z'): 1})
# Size-adjusted derandomized Hamiltonian Counter({('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 61, ('X', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 42, ('Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 41, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 39, ('X', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'X'): 39, ('X', 'Z', 'X', 'X', 'X', 'Z', 'X', 'Z'): 39, ('Y', 'Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y'): 39, ('Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y', 'Z'): 39, ('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 39, ('Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z'): 39, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'X', 'Z'): 39, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 39, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X'): 39, ('Y', 'Z', 'Y', 'Y', 'X', 'Z', 'Z', 'X'): 38, ('Z', 'X', 'Y', 'Y', 'Y', 'Z', 'Y', 'Y'): 38, ('Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'X', 'X'): 38, ('X', 'Z', 'X', 'X', 'Y', 'Z', 'Z', 'Y'): 38, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y'): 38, ('Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z'): 38, ('Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z', 'X'): 38, ('Z', 'X', 'X', 'X', 'Y', 'Y', 'Z', 'Y'): 38, ('Y', 'Y', 'X', 'X', 'X', 'Z', 'Y', 'Y'): 38, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y'): 38, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z'): 38, ('Z', 'Z', 'X', 'X', 'X', 'Z', 'Z', 'X'): 38, ('Z', 'Z', 'Y', 'Y', 'Y', 'Z', 'Z', 'Y'): 38, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X'): 38, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'X', 'X'): 38, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'X', 'X'): 38, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Y', 'Y'): 38, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'Y'): 38, ('X', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z'): 38, ('Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 38, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 38, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'X'): 38, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y'): 38, ('Y', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'Y'): 38, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 38, ('Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z'): 38, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Z'): 38, ('Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Z', 'Z'): 38, ('X', 'Y', 'Z', 'Z', 'Z', 'Y', 'Z', 'Y'): 38, ('X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 38, ('X', 'Y', 'Z', 'Y', 'X', 'X', 'Z', 'Z'): 38, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'Z'): 38})
# EXPERIMENT 0: GROUND STATE ENERGY FOUND = -1.8466170068472443
# EXPERIMENT 1: GROUND STATE ENERGY FOUND = -1.8733654591578086
# EXPERIMENT 2: GROUND STATE ENERGY FOUND = -1.8655632083470526
# EXPERIMENT 3: GROUND STATE ENERGY FOUND = -1.8632966111400253
# EXPERIMENT 4: GROUND STATE ENERGY FOUND = -1.8146252211401752
# EXPERIMENT 5: GROUND STATE ENERGY FOUND = -1.8634676976738094
# EXPERIMENT 6: GROUND STATE ENERGY FOUND = -1.8572231329870255
# EXPERIMENT 7: GROUND STATE ENERGY FOUND = -1.8438737998121144
# EXPERIMENT 8: GROUND STATE ENERGY FOUND = -1.8788187224865667
# EXPERIMENT 9: GROUND STATE ENERGY FOUND = -1.8670491434118888
# 1750 | Counter({('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'Z'): 61, ('X', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 42, ('Z', 'X', 'Z', 'Z', 'Z', 'Y', 'Z', 'Z'): 41, ('Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 39, ('X', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'X'): 39, ('X', 'Z', 'X', 'X', 'X', 'Z', 'X', 'Z'): 39, ('Y', 'Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y'): 39, ('Y', 'Z', 'Y', 'Y', 'Y', 'Z', 'Y', 'Z'): 39, ('X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'): 39, ('Y', 'Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z'): 39, ('Z', 'X', 'Z', 'Z', 'X', 'Z', 'X', 'Z'): 39, ('X', 'X', 'Z', 'Z', 'X', 'X', 'Z', 'Z'): 39, ('X', 'X', 'X', 'Z', 'X', 'X', 'X', 'X'): 39, ('Y', 'Z', 'Y', 'Y', 'X', 'Z', 'Z', 'X'): 38, ('Z', 'X', 'Y', 'Y', 'Y', 'Z', 'Y', 'Y'): 38, ('Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'X', 'X'): 38, ('X', 'Z', 'X', 'X', 'Y', 'Z', 'Z', 'Y'): 38, ('X', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Y'): 38, ('Y', 'Z', 'Y', 'Y', 'X', 'X', 'Z', 'Z'): 38, ('Y', 'Z', 'Y', 'Z', 'Z', 'X', 'Z', 'X'): 38, ('Z', 'X', 'X', 'X', 'Y', 'Y', 'Z', 'Y'): 38, ('Y', 'Y', 'X', 'X', 'X', 'Z', 'Y', 'Y'): 38, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y'): 38, ('Z', 'X', 'Z', 'X', 'Z', 'X', 'Z', 'Z'): 38, ('Z', 'Z', 'X', 'X', 'X', 'Z', 'Z', 'X'): 38, ('Z', 'Z', 'Y', 'Y', 'Y', 'Z', 'Z', 'Y'): 38, ('Z', 'Z', 'Z', 'Z', 'Z', 'X', 'Z', 'X'): 38, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'X', 'X'): 38, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'X', 'X'): 38, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Y', 'Y'): 38, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Y', 'Y'): 38, ('X', 'Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Z'): 38, ('Y', 'Z', 'Y', 'Z', 'X', 'Z', 'X', 'Z'): 38, ('X', 'Z', 'Z', 'X', 'X', 'Z', 'Z', 'X'): 38, ('Y', 'Z', 'Z', 'Y', 'X', 'Z', 'Z', 'X'): 38, ('X', 'Z', 'Z', 'X', 'Y', 'Z', 'Z', 'Y'): 38, ('Y', 'Z', 'Z', 'Y', 'Y', 'Z', 'Z', 'Y'): 38, ('Z', 'X', 'Z', 'Z', 'Z', 'Z', 'Z', 'Z'): 38, ('Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Y', 'Z'): 38, ('X', 'Z', 'X', 'Z', 'Z', 'Y', 'Z', 'Z'): 38, ('Y', 'Z', 'Y', 'Z', 'Z', 'Y', 'Z', 'Z'): 38, ('X', 'Y', 'Z', 'Z', 'Z', 'Y', 'Z', 'Y'): 38, ('X', 'X', 'Z', 'X', 'Z', 'Z', 'Z', 'Z'): 38, ('X', 'Y', 'Z', 'Y', 'X', 'X', 'Z', 'Z'): 38, ('X', 'X', 'Z', 'Z', 'X', 'X', 'X', 'Z'): 38}) | 0.02255749950121596
# Execution time =  00:13:25

# %%
import matplotlib.pyplot as plt 
points = [50, 250, 500, 750, 1000, 1250, 1500, 1750] 
num_points = len(points)
rmse_errors = [0.08042124699805506, 0.07454260102400623, 0.05238267883853363, 0.04511459414509942, 
              0.04482633974461999, 0.03788960366025773, 0.03564932219039223, 0.036982001081315746]

plt.plot([i for i in points], [rmse_errors[i] for i in range(num_points)], 'r', label='derandomized classical shadow')
plt.xlabel('Number of measurements')
plt.ylabel('Average RMSE error')
plt.legend(loc=1)
